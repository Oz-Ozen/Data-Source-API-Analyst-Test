# %% [markdown]
# # 📈 GitHub API Analyst Test
#
# This notebook is part of the Data APY Analyst technical test.
#
# It connects to the GitHub REST API to:
# - Search Public repositories
# - Retrieve commit data
# - list file contents in a repo
#
# It handles:
# - Authentication(optional token)
# - Pagination
# - Rate limiting
# - Error handling
#
# Includes helper functions for post-processin and downloading

# %%
#Imports

import requests, time, os

# %% [markdown]
# ## 🔐 Authentication
#
# The notebook use an optionan GitHub Personal Access Token (PAT)
# Git allows 5,000 request/hour if a valid token is provided, otherwise the notebook will fall back to public mode (60 request/hour)

# %%
#First validate if we have a correct token

GITHUB_TOKEN ="" #Import your token from a .env

def validate_token(token : str = None) -> dict:
    """Validate if a token is valid"""
    headers = {
        "Accept": "application/vnd.github+json",
        "Authorization": f"Bearer {token}",
        "X-GitHub-Api-Version": "2022-11-28",
    }

    try:
      resp = requests.get("https://api.github.com/user", headers=headers)
      if resp.status_code == 200:
        print(f"🔐 Authenticated as: {resp.json().get('login')}")
        return headers
      elif resp.status_code == 401:
        print("⚠️ Invalid or expired GitHub token. Falling back to unauthenticated mode.")
      else:
        print(f"❌ Auth Error {resp.status_code}:{resp.text}")

    except Exception as e:
      print(f"❌ Auth Error: {e}")
    return {
        "Accept": "application/vnd.github+json",
        "X-GitHub-Api-Version": "2022-11-28",
    }


HEADERS = validate_token(token=GITHUB_TOKEN)
if "Authorization" not in HEADERS:
  print(f"⚠️ Using public API Git Hub")
else:
  print(f"🔐 Using private API Git Hub")
# Out:
# ⚠️ Invalid or expired GitHub token. Falling back to unauthenticated mode.
# ⚠️ Using public API Git Hub

# %% [markdown]
# ## ⛓️‍💥 GitHub Helper
#
# Handles:
#
# - Authentication (use validates headers)
# - Rate limit errors (pauses)
# - Pagination (optional)
# - Normalizing results
#
# In this way, is eassier to interact with differents endpoins

# %%
def github_get(url, params=None, paginate=False):
    """GET a GitHub REST endpoint, handle rate‑limit & optional pagination."""
    all_items, page = [], 1
    while True:
      try:
        resp = requests.get(url, headers=HEADERS, params={**(params or {}), "page": page, "per_page": 100})
        if resp.status_code == 403 and resp.headers.get("X-RateLimit-Remaining") == "0":
            reset = int(resp.headers["X-RateLimit-Reset"])
            sleep_for = max(reset - time.time(), 0) + 1
            print(f"Rate‑limited. Sleeping {sleep_for:.0f}s…")
            time.sleep(sleep_for)
            continue
        resp.raise_for_status()
        data = resp.json()
        if data is None:
          print("Error: Empty response")
          break

        if isinstance(data, dict) and "items" in data:
            batch = data["items"]
        else:
            batch = data

        all_items.extend(batch)

        if not paginate or "next" not in resp.links or not batch:
            break
        page += 1
      except Exception as e:
        print(f"Error: {e}")
        break
    return all_items

# %% [markdown]
# ## 🧭 Rate Limit Handling
#
# GitHub's API has a primary rate limit of 60 requests per hour for unauthenticated users and 5,000 per hour for authenticated users.
#
# The `github_get()` function handles rate limits automatically:
#
# - It checks the `X-RateLimit-Remaining` and `X-RateLimit-Reset` headers.
# - If the limit is hit (403 response), it calculates how long to wait before retrying.
# - It then pauses using `time.sleep()` and retries the request.
#
# This prevents errors and ensures smooth API usage even in long loops.

# %%
# 1. search repositories

repos = github_get(
    "https://api.github.com/search/repositories",
    params={"q": "topic:data-science", "per_page": 5}
)
print("repos", len(repos), "repositories")
# 2. Commits from a popular repo
commits = github_get(
    "https://api.github.com/repos/pandas-dev/pandas/commits",
    params={"per_page": 5},
    paginate=True
)
print("Fetched", len(commits), "commits")

# 3. Contents of the repo root
contents = github_get(
    "https://api.github.com/repos/pandas-dev/pandas/contents",
    paginate=False
)
print("Root has", len(contents), "items")
# Out:
# repos 100 repositories
# Fetched 36249 commits
# Root has 31 items

# %% [markdown]
# ## 🔄 Reusable Functions
#
# some helpers that
#
# - Search a repositories based in a query, allows the user seach per pages
# - Obtain the repo commits and content from a given repo

# %%
def search_repositories(query: str, per_page: int = 10, pages: int =1) -> list:
    """Search for repositories using the GitHub EndPoints"""
    all_results = []

    for page in range (1, pages +1):
      results = github_get(
          url = "https://api.github.com/search/repositories",
          params = {"q": query, "per_page": per_page, "page": pages},
          paginate = False #GutHub API uses a secondary rate limit, its necesary we control de loop
      )
      all_results.extend(results)
      if len(results)<per_page:
        break

    return all_results

# %%
def get_repo_commits(owner: str, repo: str, per_page: int = 100, max_pages: int = 1):
  """ Get commits from a repository """
  all_commits =[]

  for page in range(1, max_pages + 1):
    commits = github_get(
        url = f"https://api.github.com/repos/{owner}/{repo}/commits",
        params = {"per_page": per_page, "page": page},
        paginate = False
    )
    all_commits.extend(commits)
    if len(commits) < per_page:
      break
  return all_commits

# %%
def get_repo_contents(owner: str, repo: str, path: str=""):
  """ List contents of a given path in a repository """
  contents = github_get(
      url = f"https://api.github.com/repos/{owner}/{repo}/contents/{path}",
      paginate = False
  )
  return contents

# %%
repos = search_repositories("data-science", per_page= 5, pages=1)
repos[5]
# Out:
# {'id': 43759462,
#  'node_id': 'MDEwOlJlcG9zaXRvcnk0Mzc1OTQ2Mg==',
#  'name': 'DataSciencePython',
#  'full_name': 'ujjwalkarn/DataSciencePython',
#  'private': False,
#  'owner': {'login': 'ujjwalkarn',
#   'id': 5948390,
#   'node_id': 'MDQ6VXNlcjU5NDgzOTA=',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/5948390?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/ujjwalkarn',
#   'html_url': 'https://github.com/ujjwalkarn',
#   'followers_url': 'https://api.github.com/users/ujjwalkarn/followers',
#   'following_url': 'https://api.github.com/users/ujjwalkarn/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/ujjwalkarn/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/ujjwalkarn/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/ujjwalkarn/subscriptions',
#   'organizations_url': 'https://api.github.com/users/ujjwalkarn/orgs',
#   'repos_url': 'https://api.github.com/users/ujjwalkarn/repos',
#   'events_url': 'https://api.github.com/users/ujjwalkarn/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/ujjwalkarn/received_events',
#   'type': 'User',
#   'user_view_type': 'public',
#   'site_admin': False},
#  'html_url': 'https://github.com/ujjwalkarn/DataSciencePython',
#  'description': 'common data analysis and machine learning tasks using python',
#  'fork': False,
#  'url': 'https://api.github.com/repos/ujjwalkarn/DataSciencePython',
#  'forks_url': 'https://api.github.com/repos/ujjwalkarn/DataSciencePython/forks',
#  'keys_url': 'https://api.github.com/repos/ujjwalkarn/DataSciencePython/keys{/key_id}',
#  'collaborators_url': 'https://api.github.com/repos/ujjwalkarn/DataSciencePython/collaborators{/collaborator}',
#  'teams_url': 'https://api.github.com/repos/ujjwalkarn/DataSciencePython/teams',
#  'hooks_url': 'https://api.github.com/repos/ujjwalkarn/DataSciencePython/hooks',
#  'issue_events_url': 'https://api.github.com/repos/ujjwalkarn/DataSciencePython/issues/events{/number}',
#  'events_url': 'https://api.github.com/repos/ujjwalkarn/DataSciencePython/events',
#  'assignees_url': 'https://api.github.com/repos/ujjwalkarn/DataSciencePython/assignees{/user}',
#  'branches_url': 'https://api.github.com/repos/ujjwalkarn/DataSciencePython/branches{/branch}',
#  'tags_url': 'https://api.github.com/repos/ujjwalkarn/DataSciencePython/tags',
#  'blobs_url': 'https://api.github.com/repos/ujjwalkarn/DataSciencePython/git/blobs{/sha}',
#  'git_tags_url': 'https://api.github.com/repos/ujjwalkarn/DataSciencePython/git/tags{/sha}',
#  'git_refs_url': 'https://api.github.com/repos/ujjwalkarn/DataSciencePython/git/refs{/sha}',
#  'trees_url': 'https://api.github.com/repos/ujjwalkarn/DataSciencePython/git/trees{/sha}',
#  'statuses_url': 'https://api.github.com/repos/ujjwalkarn/DataSciencePython/statuses/{sha}',
#  'languages_url': 'https://api.github.com/repos/ujjwalkarn/DataSciencePython/languages',
#  'stargazers_url': 'https://api.github.com/repos/ujjwalkarn/DataSciencePython/stargazers',
#  'contributors_url': 'https://api.github.com/repos/ujjwalkarn/DataSciencePython/contributors',
#  'subscribers_url': 'https://api.github.com/repos/ujjwalkarn/DataSciencePython/subscribers',
#  'subscription_url': 'https://api.github.com/repos/ujjwalkarn/DataSciencePython/subscription',
#  'commits_url': 'https://api.github.com/repos/ujjwalkarn/DataSciencePython/commits{/sha}',
#  'git_commits_url': 'https://api.github.com/repos/ujjwalkarn/DataSciencePython/git/commits{/sha}',
#  'comments_url': 'https://api.github.com/repos/ujjwalkarn/DataSciencePython/comments{/number}',
#  'issue_comment_url': 'https://api.github.com/repos/ujjwalkarn/DataSciencePython/issues/comments{/number}',
#  'contents_url': 'https://api.github.com/repos/ujjwalkarn/DataSciencePython/contents/{+path}',
#  'compare_url': 'https://api.github.com/repos/ujjwalkarn/DataSciencePython/compare/{base}...{head}',
#  'merges_url': 'https://api.github.com/repos/ujjwalkarn/DataSciencePython/merges',
#  'archive_url': 'https://api.github.com/repos/ujjwalkarn/DataSciencePython/{archive_format}{/ref}',
#  'downloads_url': 'https://api.github.com/repos/ujjwalkarn/DataSciencePython/downloads',
#  'issues_url': 'https://api.github.com/repos/ujjwalkarn/DataSciencePython/issues{/number}',
#  'pulls_url': 'https://api.github.com/repos/ujjwalkarn/DataSciencePython/pulls{/number}',
#  'milestones_url': 'https://api.github.com/repos/ujjwalkarn/DataSciencePython/milestones{/number}',
#  'notifications_url': 'https://api.github.com/repos/ujjwalkarn/DataSciencePython/notifications{?since,all,participating}',
#  'labels_url': 'https://api.github.com/repos/ujjwalkarn/DataSciencePython/labels{/name}',
#  'releases_url': 'https://api.github.com/repos/ujjwalkarn/DataSciencePython/releases{/id}',
#  'deployments_url': 'https://api.github.com/repos/ujjwalkarn/DataSciencePython/deployments',
#  'created_at': '2015-10-06T15:26:08Z',
#  'updated_at': '2025-07-09T23:33:01Z',
#  'pushed_at': '2024-04-03T10:37:58Z',
#  'git_url': 'git://github.com/ujjwalkarn/DataSciencePython.git',
#  'ssh_url': 'git@github.com:ujjwalkarn/DataSciencePython.git',
#  'clone_url': 'https://github.com/ujjwalkarn/DataSciencePython.git',
#  'svn_url': 'https://github.com/ujjwalkarn/DataSciencePython',
#  'homepage': '',
#  'size': 83,
#  'stargazers_count': 5466,
#  'watchers_count': 5466,
#  'language': 'Python',
#  'has_issues': True,
#  'has_projects': True,
#  'has_downloads': True,
#  'has_wiki': True,
#  'has_pages': False,
#  'has_discussions': False,
#  'forks_count': 1507,
#  'mirror_url': None,
#  'archived': False,
#  'disabled': False,
#  'open_issues_count': 12,
#  'license': {'key': 'mit',
#   'name': 'MIT License',
#   'spdx_id': 'MIT',
#   'url': 'https://api.github.com/licenses/mit',
#   'node_id': 'MDc6TGljZW5zZTEz'},
#  'allow_forking': True,
#  'is_template': False,
#  'web_commit_signoff_required': False,
#  'topics': ['data-science', 'data-scientists', 'python', 'python-tutorial'],
#  'visibility': 'public',
#  'forks': 1507,
#  'open_issues': 12,
#  'watchers': 5466,
#  'default_branch': 'master',
#  'permissions': {'admin': False,
#   'maintain': False,
#   'push': False,
#   'triage': False,
#   'pull': True},
#  'score': 1.0}

# %%
commits = get_repo_commits("fastai", "fastai", per_page=100, max_pages=1)
commits[0]
# Out:
# {'sha': '1ac4ee147baf86d2f66f13da9d755a4970f1160b',
#  'node_id': 'C_kwDOBiNAztoAKDFhYzRlZTE0N2JhZjg2ZDJmNjZmMTNkYTlkNzU1YTQ5NzBmMTE2MGI',
#  'commit': {'author': {'name': 'Jeremy Howard',
#    'email': 'github@jhoward.fastmail.fm',
#    'date': '2025-06-05T22:32:37Z'},
#   'committer': {'name': 'GitHub',
#    'email': 'noreply@github.com',
#    'date': '2025-06-05T22:32:37Z'},
#   'message': 'Merge pull request #4098 from Timmecom/update-plot-lr-find\n\nUpdate plot lr find',
#   'tree': {'sha': 'd035f20c1f2a1ac6963fa6e8c4d276cceaf34ce3',
#    'url': 'https://api.github.com/repos/fastai/fastai/git/trees/d035f20c1f2a1ac6963fa6e8c4d276cceaf34ce3'},
#   'url': 'https://api.github.com/repos/fastai/fastai/git/commits/1ac4ee147baf86d2f66f13da9d755a4970f1160b',
#   'comment_count': 0,
#   'verification': {'verified': True,
#    'reason': 'valid',
#    'signature': '-----BEGIN PGP SIGNATURE-----\n\\nR/WYJqdn5kttq1f9LwWm\n=cJ48\n-----END PGP SIGNATURE-----\n',
#    'payload': 'tree d035f20c1f2a1ac6963fa6e8c4d276cceaf34ce3\nparent 8546a06e4792276561c189391fc1bf38824b0bb0\nparent c5df718db7f3ff7b72928dd21e28026d525bfb88\nauthor Jeremy Howard <github@jhoward.fastmail.fm> 1749162757 +1000\ncommitter GitHub <noreply@github.com> 1749162757 +1000\n\nMerge pull request #4098 from Timmecom/update-plot-lr-find\n\nUpdate plot lr find',
#    'verified_at': '2025-06-05T22:37:40Z'}},
#  'url': 'https://api.github.com/repos/fastai/fastai/commits/1ac4ee147baf86d2f66f13da9d755a4970f1160b',
#  'html_url': 'https://github.com/fastai/fastai/commit/1ac4ee147baf86d2f66f13da9d755a4970f1160b',
#  'comments_url': 'https://api.github.com/repos/fastai/fastai/commits/1ac4ee147baf86d2f66f13da9d755a4970f1160b/comments',
#  'author': {'login': 'jph00',
#   'id': 346999,
#   'node_id': 'MDQ6VXNlcjM0Njk5OQ==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/346999?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/jph00',
#   'html_url': 'https://github.com/jph00',
#   'followers_url': 'https://api.github.com/users/jph00/followers',
#   'following_url': 'https://api.github.com/users/jph00/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/jph00/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/jph00/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/jph00/subscriptions',
#   'organizations_url': 'https://api.github.com/users/jph00/orgs',
#   'repos_url': 'https://api.github.com/users/jph00/repos',
#   'events_url': 'https://api.github.com/users/jph00/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/jph00/received_events',
#   'type': 'User',
#   'user_view_type': 'public',
#   'site_admin': False},
#  'committer': {'login': 'web-flow',
#   'id': 19864447,
#   'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/web-flow',
#   'html_url': 'https://github.com/web-flow',
#   'followers_url': 'https://api.github.com/users/web-flow/followers',
#   'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#   'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#   'repos_url': 'https://api.github.com/users/web-flow/repos',
#   'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#   'type': 'User',
#   'user_view_type': 'public',
#   'site_admin': False},
#  'parents': [{'sha': '8546a06e4792276561c189391fc1bf38824b0bb0',
#    'url': 'https://api.github.com/repos/fastai/fastai/commits/8546a06e4792276561c189391fc1bf38824b0bb0',
#    'html_url': 'https://github.com/fastai/fastai/commit/8546a06e4792276561c189391fc1bf38824b0bb0'},
#   {'sha': 'c5df718db7f3ff7b72928dd21e28026d525bfb88',
#    'url': 'https://api.github.com/repos/fastai/fastai/commits/c5df718db7f3ff7b72928dd21e28026d525bfb88',
#    'html_url': 'https://github.com/fastai/fastai/commit/c5df718db7f3ff7b72928dd21e28026d525bfb88'}]}

# %%
contents = get_repo_contents("fastai", "fastai", path="")
contents[0]
# Out:
# {'name': '.devcontainer.json',
#  'path': '.devcontainer.json',
#  'sha': '5c93e3519d22eedfe281bc5b0bcf29029d4ee825',
#  'size': 545,
#  'url': 'https://api.github.com/repos/fastai/fastai/contents/.devcontainer.json?ref=main',
#  'html_url': 'https://github.com/fastai/fastai/blob/main/.devcontainer.json',
#  'git_url': 'https://api.github.com/repos/fastai/fastai/git/blobs/5c93e3519d22eedfe281bc5b0bcf29029d4ee825',
#  'download_url': 'https://raw.githubusercontent.com/fastai/fastai/main/.devcontainer.json',
#  'type': 'file',
#  '_links': {'self': 'https://api.github.com/repos/fastai/fastai/contents/.devcontainer.json?ref=main',
#   'git': 'https://api.github.com/repos/fastai/fastai/git/blobs/5c93e3519d22eedfe281bc5b0bcf29029d4ee825',
#   'html': 'https://github.com/fastai/fastai/blob/main/.devcontainer.json'}}

# %% [markdown]
# ## 📦 Bonus Functions
#
# This functions helps the user:
# - Clean commits to extract important information
# - Filter repositories by stars or language
# - Download files or entire repositores (zip)

# %%
def clean_commits(raw_commits):
    """Extract useful fields from raw commit data."""
    cleaned = []
    for commit in raw_commits:
        cleaned.append({
            "sha": commit.get("sha"),
            "author": commit.get("commit", {}).get("author", {}).get("name"),
            "date": commit.get("commit", {}).get("author", {}).get("date"),
            "message": commit.get("commit", {}).get("message"),
            "url": commit.get("html_url"),
        })
    return cleaned

clean_commits(commits)
# Out:
# [{'sha': '1ac4ee147baf86d2f66f13da9d755a4970f1160b',
#   'author': 'Jeremy Howard',
#   'date': '2025-06-05T22:32:37Z',
#   'message': 'Merge pull request #4098 from Timmecom/update-plot-lr-find\n\nUpdate plot lr find',
#   'url': 'https://github.com/fastai/fastai/commit/1ac4ee147baf86d2f66f13da9d755a4970f1160b'},
#  {'sha': 'c5df718db7f3ff7b72928dd21e28026d525bfb88',
#   'author': 'Timmecom',
#   'date': '2025-06-05T20:20:27Z',
#   'message': 'Ran nbdev_export',
#   'url': 'https://github.com/fastai/fastai/commit/c5df718db7f3ff7b72928dd21e28026d525bfb88'},
#  {'sha': 'a08b61d99a1b00ff7a1cb857d02d5bb9cdb0ba4a',
#   'author': 'Timmecom',
#   'date': '2025-06-04T10:59:13Z',
#   'message': 'Add return statement for figure in plot_lr_find method within the notebook.',
#   'url': 'https://github.com/fastai/fastai/commit/a08b61d99a1b00ff7a1cb857d02d5bb9cdb0ba4a'},
#  {'sha': '76457f3a094e874c44887df3ccc6fb037f925c83',
#   'author': 'Timmecom',
#   'date': '2025-06-04T10:53:52Z',
#   'message': 'Remove the return statement from the .py file which was autogenerated from the notebooks',
#   'url': 'https://github.com/fastai/fastai/commit/76457f3a094e874c44887df3ccc6fb037f925c83'},
#  {'sha': '1f24b4254a4bb3ec798aacac0c460a3beb28cb99',
#   'author': 'Timmecom',
#   'date': '2025-06-03T19:27:39Z',
#   'message': 'Updated the implementation to fit the overall code style',
#   'url': 'https://github.com/fastai/fastai/commit/1f24b4254a4bb3ec798aacac0c460a3beb28cb99'},
#  {'sha': '948e20ecbfa2d798f1a58345011a5fcd74ae06ed',
#   'author': 'Timmecom',
#   'date': '2025-06-03T19:19:20Z',
#   'message': 'Add return statement for figure in plot_lr_find method',
#   'url': 'https://github.com/fastai/fastai/commit/948e20ecbfa2d798f1a58345011a5fcd74ae06ed'},
#  {'sha': '8546a06e4792276561c189391fc1bf38824b0bb0',
#   'author': 'Jeremy Howard',
#   'date': '2025-05-24T03:53:00Z',
#   'message': 'bump',
#   'url': 'https://github.com/fastai/fastai/commit/8546a06e4792276561c189391fc1bf38824b0bb0'},
#  {'sha': 'd68f909e3046274d7f580374c3f85abdc5ef22ee',
#   'author': 'Jeremy Howard',
#   'date': '2025-05-24T03:52:47Z',
#   'message': 'release',
#   'url': 'https://github.com/fastai/fastai/commit/d68f909e3046274d7f580374c3f85abdc5ef22ee'},
#  {'sha': '9178dd16496630816a9ac889981eead2279b3554',
#   'author': 'Jeremy Howard',
#   'date': '2025-05-23T23:31:26Z',
#   'message': 'Merge pull request #4095 from tonyhoo/torch_update\n\nupdate torch version to 2.7',
#   'url': 'https://github.com/fastai/fastai/commit/9178dd16496630816a9ac889981eead2279b3554'},
#  {'sha': 'f213bbc3d459176a4fd7c71c5e415cceb70d9977',
#   'author': 'tonyhu',
#   'date': '2025-05-23T16:06:14Z',
#   'message': 'update torch version',
#   'url': 'https://github.com/fastai/fastai/commit/f213bbc3d459176a4fd7c71c5e415cceb70d9977'},
#  {'sha': 'f4de849baa79b64792ae5e98ef37e5f8fa4be66f',
#   'author': 'Jeremy Howard',
#   'date': '2025-04-19T19:47:43Z',
#   'message': 'Update docs.yml',
#   'url': 'https://github.com/fastai/fastai/commit/f4de849baa79b64792ae5e98ef37e5f8fa4be66f'},
#  {'sha': '7638d4717cd901ad1d2d7923d77ef184660cb2d3',
#   'author': 'Jeremy Howard',
#   'date': '2025-04-18T21:15:15Z',
#   'message': 'bump',
#   'url': 'https://github.com/fastai/fastai/commit/7638d4717cd901ad1d2d7923d77ef184660cb2d3'},
#  {'sha': '0daeff32fe102c6c5e818e8d97d698cd635a8b47',
#   'author': 'Jeremy Howard',
#   'date': '2025-04-18T21:14:55Z',
#   'message': 'release',
#   'url': 'https://github.com/fastai/fastai/commit/0daeff32fe102c6c5e818e8d97d698cd635a8b47'},
#  {'sha': '2d0f76630e02a43df8574ee5181d1274b38ef5fb',
#   'author': 'Jeremy Howard',
#   'date': '2025-04-18T21:13:32Z',
#   'message': 'dep',
#   'url': 'https://github.com/fastai/fastai/commit/2d0f76630e02a43df8574ee5181d1274b38ef5fb'},
#  {'sha': '439f47a944bc0c15605a5802b1ab43c515d3cc8b',
#   'author': 'Jeremy Howard',
#   'date': '2025-04-08T19:41:23Z',
#   'message': 'Merge pull request #4091 from warner-benjamin/fix_export_test\n\nFix export test by running loaded model on GPU',
#   'url': 'https://github.com/fastai/fastai/commit/439f47a944bc0c15605a5802b1ab43c515d3cc8b'},
#  {'sha': '077a01b963a3aa22dea6b542c7617da80cf28789',
#   'author': 'Benjamin Warner',
#   'date': '2025-04-08T15:28:33Z',
#   'message': 'Fix test by running loaded model on GPU\n\nCo-authored-by:  Rens Dimmendaal <rensdimmendaal@users.noreply.github.com>',
#   'url': 'https://github.com/fastai/fastai/commit/077a01b963a3aa22dea6b542c7617da80cf28789'},
#  {'sha': 'eee543ec28326714ad49daa82633b49410083a0a',
#   'author': 'Jeremy Howard',
#   'date': '2025-04-02T23:06:03Z',
#   'message': 'pyproject',
#   'url': 'https://github.com/fastai/fastai/commit/eee543ec28326714ad49daa82633b49410083a0a'},
#  {'sha': '21b1d65e5c98dbe0fe791fb362580c43ef41b114',
#   'author': 'Jeremy Howard',
#   'date': '2025-04-01T21:06:36Z',
#   'message': 'Merge pull request #4088 from warner-benjamin/add_some_missing_docment_tables\n\nSwitch callable to Callable and generate missing docment tables',
#   'url': 'https://github.com/fastai/fastai/commit/21b1d65e5c98dbe0fe791fb362580c43ef41b114'},
#  {'sha': '59de729fdf58153fc1c453c72a5aaf1bb1aefc07',
#   'author': 'Benjamin Warner',
#   'date': '2025-04-01T00:32:46Z',
#   'message': 'Switch callable to Callable and generate missing docment tables',
#   'url': 'https://github.com/fastai/fastai/commit/59de729fdf58153fc1c453c72a5aaf1bb1aefc07'},
#  {'sha': '84bd284742ecc03dba11a41c71c4843800eaf1e2',
#   'author': 'Jeremy Howard',
#   'date': '2025-03-29T19:58:45Z',
#   'message': 'Merge pull request #4083 from RensDimmendaal/make-export-plum-compatible\n\nFix fasttransform/plum-dispatch adoption errors',
#   'url': 'https://github.com/fastai/fastai/commit/84bd284742ecc03dba11a41c71c4843800eaf1e2'},
#  {'sha': '734f12f30c42eef725eab890b007d8671c512e9d',
#   'author': 'Jeremy Howard',
#   'date': '2025-03-29T19:36:29Z',
#   'message': 'main',
#   'url': 'https://github.com/fastai/fastai/commit/734f12f30c42eef725eab890b007d8671c512e9d'},
#  {'sha': '812431bef51f7f177a1b3526c82e5c790cdf4674',
#   'author': 'Jeremy Howard',
#   'date': '2025-03-29T18:28:26Z',
#   'message': 'Merge pull request #4087 from warner-benjamin/numpy_dtypes_safeload\n\nPyTorch 2.6 safe loading support for fastai optimizers',
#   'url': 'https://github.com/fastai/fastai/commit/812431bef51f7f177a1b3526c82e5c790cdf4674'},
#  {'sha': '20a98506c8e14d4874209897594da2d082c11713',
#   'author': 'Benjamin Warner',
#   'date': '2025-03-26T20:55:46Z',
#   'message': 'add numpy dtypes to to safe_globals so optimizer hypers can load',
#   'url': 'https://github.com/fastai/fastai/commit/20a98506c8e14d4874209897594da2d082c11713'},
#  {'sha': 'c7190a1384026f2f6f1f3d4ca92a28126b1c07cc',
#   'author': 'Rens',
#   'date': '2025-03-24T18:39:57Z',
#   'message': 'add cloudpickle and export test\n\nCo-Authored-By: Benjamin Warner <51142400+warner-benjamin@users.noreply.github.com>',
#   'url': 'https://github.com/fastai/fastai/commit/c7190a1384026f2f6f1f3d4ca92a28126b1c07cc'},
#  {'sha': '43ac38e234f529af2853f55acb5912120630d95b',
#   'author': 'Rens',
#   'date': '2025-03-22T19:23:38Z',
#   'message': 'set minimum python version to 3.10',
#   'url': 'https://github.com/fastai/fastai/commit/43ac38e234f529af2853f55acb5912120630d95b'},
#  {'sha': '32810c2ac173eeaba583ee1daff2ab1d24630b61',
#   'author': 'Rens',
#   'date': '2025-03-20T13:50:18Z',
#   'message': 'Update GitHub Actions workflow to install libraries from main branch of answerdotai repositories (#4080)',
#   'url': 'https://github.com/fastai/fastai/commit/32810c2ac173eeaba583ee1daff2ab1d24630b61'},
#  {'sha': 'b7a13c33971586015bf63384058d074432682844',
#   'author': 'Jeremy Howard',
#   'date': '2025-03-18T05:49:41Z',
#   'message': 'Update main.yml',
#   'url': 'https://github.com/fastai/fastai/commit/b7a13c33971586015bf63384058d074432682844'},
#  {'sha': 'f8c971116fe80384b53e3cdf76f38b2618ca0f93',
#   'author': 'Jeremy Howard',
#   'date': '2025-03-18T05:35:11Z',
#   'message': 'bump',
#   'url': 'https://github.com/fastai/fastai/commit/f8c971116fe80384b53e3cdf76f38b2618ca0f93'},
#  {'sha': 'e357206e69c51f08056b5e0e1fe2ba6733f7d8ee',
#   'author': 'Jeremy Howard',
#   'date': '2025-03-18T05:34:56Z',
#   'message': 'debump',
#   'url': 'https://github.com/fastai/fastai/commit/e357206e69c51f08056b5e0e1fe2ba6733f7d8ee'},
#  {'sha': 'ce1b3b6db1bb45dd40597a6885ad4db73d5e5e70',
#   'author': 'Jeremy Howard',
#   'date': '2025-03-18T05:34:32Z',
#   'message': 'bump',
#   'url': 'https://github.com/fastai/fastai/commit/ce1b3b6db1bb45dd40597a6885ad4db73d5e5e70'},
#  {'sha': '5e9dc8756af16322a1fb18a962047cbf0d1ada04',
#   'author': 'Jeremy Howard',
#   'date': '2025-03-18T05:34:12Z',
#   'message': 'release',
#   'url': 'https://github.com/fastai/fastai/commit/5e9dc8756af16322a1fb18a962047cbf0d1ada04'},
#  {'sha': 'a1243f3ffa42331b9f50eb6f5a8b06a166e26126',
#   'author': 'Jeremy Howard',
#   'date': '2025-03-18T05:33:11Z',
#   'message': 'bump',
#   'url': 'https://github.com/fastai/fastai/commit/a1243f3ffa42331b9f50eb6f5a8b06a166e26126'},
#  {'sha': 'aa0f9bc7d32f82f7973476abe7fdfb7ee3ca9cd4',
#   'author': 'Jeremy Howard',
#   'date': '2025-03-18T05:24:34Z',
#   'message': 'Merge pull request #4074 from RensDimmendaal/use-fasttransform\n\nUse fasttransform',
#   'url': 'https://github.com/fastai/fastai/commit/aa0f9bc7d32f82f7973476abe7fdfb7ee3ca9cd4'},
#  {'sha': '52fafb8ff229a553fda4127c5c1b56c9057109c0',
#   'author': 'Jeremy Howard',
#   'date': '2025-03-18T05:18:58Z',
#   'message': "Merge branch 'main' into use-fasttransform",
#   'url': 'https://github.com/fastai/fastai/commit/52fafb8ff229a553fda4127c5c1b56c9057109c0'},
#  {'sha': '925a097270e04dc8ac315bc12660d31dfb4a51e4',
#   'author': 'Jeremy Howard',
#   'date': '2025-03-12T19:09:53Z',
#   'message': 'bump',
#   'url': 'https://github.com/fastai/fastai/commit/925a097270e04dc8ac315bc12660d31dfb4a51e4'},
#  {'sha': '330dbecaed462af4c42e2236e67d2b73c44fb807',
#   'author': 'Jeremy Howard',
#   'date': '2025-03-12T19:09:11Z',
#   'message': 'release',
#   'url': 'https://github.com/fastai/fastai/commit/330dbecaed462af4c42e2236e67d2b73c44fb807'},
#  {'sha': '900769f6ea2bb7d84ed8059fa4a633512bc0065c',
#   'author': 'Jeremy Howard',
#   'date': '2025-03-12T19:08:56Z',
#   'message': 'bump',
#   'url': 'https://github.com/fastai/fastai/commit/900769f6ea2bb7d84ed8059fa4a633512bc0065c'},
#  {'sha': '4633a6527128c553643ccfd6794305e0cae7fbec',
#   'author': 'Jeremy Howard',
#   'date': '2025-03-12T19:07:38Z',
#   'message': 'Merge pull request #4058 from rother/update-conda-instructions\n\nUpdated install instructions for conda in readme.',
#   'url': 'https://github.com/fastai/fastai/commit/4633a6527128c553643ccfd6794305e0cae7fbec'},
#  {'sha': '4570572637e93abb17c6a8e07f8f7d96386e2430',
#   'author': 'Jeremy Howard',
#   'date': '2025-03-12T19:05:43Z',
#   'message': 'Merge pull request #4078 from warner-benjamin/pytorch26\n\nAdd support for PyTorch 2.6',
#   'url': 'https://github.com/fastai/fastai/commit/4570572637e93abb17c6a8e07f8f7d96386e2430'},
#  {'sha': '5cb38afc9e8af8f6b2e89e850faff0c396375b61',
#   'author': 'Benjamin Warner',
#   'date': '2025-03-12T16:59:05Z',
#   'message': 'add support for pytorch 2.6',
#   'url': 'https://github.com/fastai/fastai/commit/5cb38afc9e8af8f6b2e89e850faff0c396375b61'},
#  {'sha': '27ab7158b4a9d218c59beadc12e883b887019118',
#   'author': 'Jeremy Howard',
#   'date': '2025-03-12T04:16:43Z',
#   'message': 'clean',
#   'url': 'https://github.com/fastai/fastai/commit/27ab7158b4a9d218c59beadc12e883b887019118'},
#  {'sha': '40750d813bbe808eed0f0bb975377646cbc72f64',
#   'author': 'Jeremy Howard',
#   'date': '2025-03-12T00:04:07Z',
#   'message': 'Merge pull request #4077 from annakavosh/fix-broken-colab-link\n\nFix broken Colab link - Issue #4069',
#   'url': 'https://github.com/fastai/fastai/commit/40750d813bbe808eed0f0bb975377646cbc72f64'},
#  {'sha': '88610d9a63086ed28ddf7eeb68da79c32a8a4e00',
#   'author': 'Anahita Kavosh',
#   'date': '2025-03-10T22:03:48Z',
#   'message': 'Fix broken Colab link in index.ipynb',
#   'url': 'https://github.com/fastai/fastai/commit/88610d9a63086ed28ddf7eeb68da79c32a8a4e00'},
#  {'sha': 'd664d6a79802d689ed75e0f90d0220b129ff4918',
#   'author': 'Anahita Kavosh',
#   'date': '2025-03-10T20:20:34Z',
#   'message': 'Fix broken Colab link',
#   'url': 'https://github.com/fastai/fastai/commit/d664d6a79802d689ed75e0f90d0220b129ff4918'},
#  {'sha': '651d58f71978e665e0d54487ac3b28b70ef74cb1',
#   'author': 'Rens Dimmendaal',
#   'date': '2025-03-03T20:10:33Z',
#   'message': 'add fasttransform as dependency',
#   'url': 'https://github.com/fastai/fastai/commit/651d58f71978e665e0d54487ac3b28b70ef74cb1'},
#  {'sha': '33ffab3b6daf055d98b3b1b84b2eb1a9b5143944',
#   'author': 'Rens Dimmendaal',
#   'date': '2025-03-03T19:53:52Z',
#   'message': 'update fastcore requirement to >=1.8.0,<1.9',
#   'url': 'https://github.com/fastai/fastai/commit/33ffab3b6daf055d98b3b1b84b2eb1a9b5143944'},
#  {'sha': '15b034463cb8794af5ebf6ac12d18ba7f95bb783',
#   'author': 'Jeremy Raymond',
#   'date': '2025-02-26T18:27:36Z',
#   'message': 'Fix #4072 untar_data() ignores provided base\n\nUpdated untar_data() to pass a None config to FastDownload when an overridden\nbase is provided. FastDownload _always_ uses a provided config object and\nignores base if both are given.',
#   'url': 'https://github.com/fastai/fastai/commit/15b034463cb8794af5ebf6ac12d18ba7f95bb783'},
#  {'sha': 'd797fcd963039877e2e9048de32e6e26481cc558',
#   'author': 'Jeremy Howard',
#   'date': '2025-02-28T20:27:58Z',
#   'message': 'Merge pull request #4073 from jeraymond/4072-fix-untar_data-ignores-base\n\nFix #4072 untar_data() ignores provided base',
#   'url': 'https://github.com/fastai/fastai/commit/d797fcd963039877e2e9048de32e6e26481cc558'},
#  {'sha': '9c367bfb27d1cb2629f91ced57baa52c880e9e98',
#   'author': 'Jeremy Raymond',
#   'date': '2025-02-26T18:27:36Z',
#   'message': 'Fix #4072 untar_data() ignores provided base\n\nUpdated untar_data() to pass a None config to FastDownload when an overridden\nbase is provided. FastDownload _always_ uses a provided config object and\nignores base if both are given.',
#   'url': 'https://github.com/fastai/fastai/commit/9c367bfb27d1cb2629f91ced57baa52c880e9e98'},
#  {'sha': 'd9d5758f58a4d8122624f56160f4141018cb8073',
#   'author': 'Rens Dimmendaal',
#   'date': '2025-01-27T14:26:32Z',
#   'message': 'updated prints w new Transform repr',
#   'url': 'https://github.com/fastai/fastai/commit/d9d5758f58a4d8122624f56160f4141018cb8073'},
#  {'sha': 'beb4e43dd8f3925c6c994fec9b54cc626259386f',
#   'author': 'Rens Dimmendaal',
#   'date': '2025-01-27T14:11:36Z',
#   'message': 'more moves from fastcore.typedispatch -> plum.dispatch',
#   'url': 'https://github.com/fastai/fastai/commit/beb4e43dd8f3925c6c994fec9b54cc626259386f'},
#  {'sha': '7b529ee917a057548bef8437d69d90c0067f15a4',
#   'author': 'Rens Dimmendaal',
#   'date': '2025-01-27T14:10:03Z',
#   'message': 'add setups to docs, not fasttransform related but broke running of nbdev_test',
#   'url': 'https://github.com/fastai/fastai/commit/7b529ee917a057548bef8437d69d90c0067f15a4'},
#  {'sha': '1509450768450923434d88500421e6d5b24c53d3',
#   'author': 'Rens Dimmendaal',
#   'date': '2025-01-27T14:08:57Z',
#   'message': 'fastcore.typedispatch -> plum.dispatch',
#   'url': 'https://github.com/fastai/fastai/commit/1509450768450923434d88500421e6d5b24c53d3'},
#  {'sha': '0c6aca08eff1ca55ca74780a98f7b1b0bf8de452',
#   'author': 'Rens Dimmendaal',
#   'date': '2025-01-27T13:47:46Z',
#   'message': 'make show_batch fasttransform compatible',
#   'url': 'https://github.com/fastai/fastai/commit/0c6aca08eff1ca55ca74780a98f7b1b0bf8de452'},
#  {'sha': 'b5d3a61f2e6d19118af6d0ea722c2a4becf564fa',
#   'author': 'Rens Dimmendaal',
#   'date': '2025-01-27T13:11:32Z',
#   'message': 'use fasttransform',
#   'url': 'https://github.com/fastai/fastai/commit/b5d3a61f2e6d19118af6d0ea722c2a4becf564fa'},
#  {'sha': '798b2bdb821863364efe271160f530c3043edff4',
#   'author': 'Kristian Rother',
#   'date': '2025-01-15T12:57:14Z',
#   'message': 'Updated index.ipynb with fixed conda instructions',
#   'url': 'https://github.com/fastai/fastai/commit/798b2bdb821863364efe271160f530c3043edff4'},
#  {'sha': '747ef49792ba2e49347edc8be59cf26b255f55d8',
#   'author': 'rother',
#   'date': '2024-12-19T14:37:29Z',
#   'message': 'Updated install instructions for conda. This installs the latest version.',
#   'url': 'https://github.com/fastai/fastai/commit/747ef49792ba2e49347edc8be59cf26b255f55d8'},
#  {'sha': 'b624c9f54a170e721e77be254e407be8624f294a',
#   'author': 'Jeremy Howard',
#   'date': '2024-12-14T04:24:41Z',
#   'message': 'rm',
#   'url': 'https://github.com/fastai/fastai/commit/b624c9f54a170e721e77be254e407be8624f294a'},
#  {'sha': 'e92d2135db9874271bcd8c84c2f469297901ef39',
#   'author': 'Jeremy Howard',
#   'date': '2024-12-14T04:24:17Z',
#   'message': 'main.yml',
#   'url': 'https://github.com/fastai/fastai/commit/e92d2135db9874271bcd8c84c2f469297901ef39'},
#  {'sha': 'ec4f4d291d2d5aa914220022f11957878e5ede93',
#   'author': 'Jeremy Howard',
#   'date': '2024-11-17T08:15:54Z',
#   'message': 'pyproject.toml',
#   'url': 'https://github.com/fastai/fastai/commit/ec4f4d291d2d5aa914220022f11957878e5ede93'},
#  {'sha': '9d9f51f0e241a0d4348b88eb7588eb5c7c23b969',
#   'author': 'Jeremy Howard',
#   'date': '2024-10-19T04:07:43Z',
#   'message': 'Merge pull request #3992 from fastai/dependabot/github_actions/actions/setup-python-5\n\nBump actions/setup-python from 4 to 5',
#   'url': 'https://github.com/fastai/fastai/commit/9d9f51f0e241a0d4348b88eb7588eb5c7c23b969'},
#  {'sha': '3cc2e635312a1cec326207fc3557a346dcd73ac9',
#   'author': 'Jeremy Howard',
#   'date': '2024-10-19T04:07:24Z',
#   'message': 'Merge pull request #4002 from fastai/dependabot/github_actions/actions/cache-4\n\nBump actions/cache from 3 to 4',
#   'url': 'https://github.com/fastai/fastai/commit/3cc2e635312a1cec326207fc3557a346dcd73ac9'},
#  {'sha': 'b8f01d6a87bb526edb2a528f86f4e40f066aa3f4',
#   'author': 'Jeremy Howard',
#   'date': '2024-10-19T04:02:40Z',
#   'message': 'CI',
#   'url': 'https://github.com/fastai/fastai/commit/b8f01d6a87bb526edb2a528f86f4e40f066aa3f4'},
#  {'sha': 'c71986367ab37c6e027307dbdef0583a34c65b0e',
#   'author': 'Jeremy Howard',
#   'date': '2024-10-19T04:02:03Z',
#   'message': 'py bump',
#   'url': 'https://github.com/fastai/fastai/commit/c71986367ab37c6e027307dbdef0583a34c65b0e'},
#  {'sha': 'bcdcbb9c819d55b30b766ed297aa2436a2efa586',
#   'author': 'Jeremy Howard',
#   'date': '2024-10-19T04:01:36Z',
#   'message': 'bump',
#   'url': 'https://github.com/fastai/fastai/commit/bcdcbb9c819d55b30b766ed297aa2436a2efa586'},
#  {'sha': 'e5ae977fde1a7dc799572a39c442f935d82c0d35',
#   'author': 'Jeremy Howard',
#   'date': '2024-10-19T03:20:10Z',
#   'message': 'release',
#   'url': 'https://github.com/fastai/fastai/commit/e5ae977fde1a7dc799572a39c442f935d82c0d35'},
#  {'sha': '08952612b66f54fa9143b95debc1249aebf1e115',
#   'author': 'Jeremy Howard',
#   'date': '2024-10-19T03:19:44Z',
#   'message': 'bump',
#   'url': 'https://github.com/fastai/fastai/commit/08952612b66f54fa9143b95debc1249aebf1e115'},
#  {'sha': '9498eebea937c94eee3f50a7e01e838c853a77fd',
#   'author': 'Jeremy Howard',
#   'date': '2024-10-19T03:19:24Z',
#   'message': 'release',
#   'url': 'https://github.com/fastai/fastai/commit/9498eebea937c94eee3f50a7e01e838c853a77fd'},
#  {'sha': '80e032b0eb98860166f3ace7d2408ac210174b12',
#   'author': 'Jeremy Howard',
#   'date': '2024-09-25T15:53:46Z',
#   'message': 'Fix SyntaxWarning',
#   'url': 'https://github.com/fastai/fastai/commit/80e032b0eb98860166f3ace7d2408ac210174b12'},
#  {'sha': 'dfba2911b676f2833f36a70de4266fbebd9d5c49',
#   'author': 'Jeremy Howard',
#   'date': '2024-09-19T06:59:21Z',
#   'message': 'Merge pull request #4049 from CraigRichards/master\n\nMinor update to documentation',
#   'url': 'https://github.com/fastai/fastai/commit/dfba2911b676f2833f36a70de4266fbebd9d5c49'},
#  {'sha': '1dd2d1b24f41a700c6ca5ddba30c878135abe79f',
#   'author': 'Craig Richards',
#   'date': '2024-09-11T05:27:28Z',
#   'message': 'Minor update to documentation',
#   'url': 'https://github.com/fastai/fastai/commit/1dd2d1b24f41a700c6ca5ddba30c878135abe79f'},
#  {'sha': '9ef68374aee798c16fa23ad2e428fa6ae7bd9aed',
#   'author': 'Jeremy Howard',
#   'date': '2024-08-27T06:50:42Z',
#   'message': 'release',
#   'url': 'https://github.com/fastai/fastai/commit/9ef68374aee798c16fa23ad2e428fa6ae7bd9aed'},
#  {'sha': '2ab4bcc489222e3707999dfc620b9e1dc53a19ed',
#   'author': 'Jeremy Howard',
#   'date': '2024-08-27T06:50:11Z',
#   'message': 'fastcore dep',
#   'url': 'https://github.com/fastai/fastai/commit/2ab4bcc489222e3707999dfc620b9e1dc53a19ed'},
#  {'sha': '4dbd8199d97cc663543f841c527fefddfe96799c',
#   'author': 'Jeremy Howard',
#   'date': '2024-08-25T20:17:11Z',
#   'message': 'fix badge',
#   'url': 'https://github.com/fastai/fastai/commit/4dbd8199d97cc663543f841c527fefddfe96799c'},
#  {'sha': '64092dbff59c913950b794799ee6d8f43a8cc705',
#   'author': 'Jeremy Howard',
#   'date': '2024-08-25T20:10:56Z',
#   'message': 'fixes #4044',
#   'url': 'https://github.com/fastai/fastai/commit/64092dbff59c913950b794799ee6d8f43a8cc705'},
#  {'sha': '85625d621ff1a068f114a3318cc31b927019de05',
#   'author': 'Jeremy Howard',
#   'date': '2024-07-30T22:42:18Z',
#   'message': 'bump',
#   'url': 'https://github.com/fastai/fastai/commit/85625d621ff1a068f114a3318cc31b927019de05'},
#  {'sha': '06ae707580babe47f26ada80912f0d698fdd004c',
#   'author': 'Jeremy Howard',
#   'date': '2024-07-30T22:26:19Z',
#   'message': 'release',
#   'url': 'https://github.com/fastai/fastai/commit/06ae707580babe47f26ada80912f0d698fdd004c'},
#  {'sha': 'bf54bb432f9a219106fa890cd83aa481d0559390',
#   'author': 'Jeremy Howard',
#   'date': '2024-07-30T22:24:23Z',
#   'message': 'clean',
#   'url': 'https://github.com/fastai/fastai/commit/bf54bb432f9a219106fa890cd83aa481d0559390'},
#  {'sha': 'c19f8c627162f07135a0b2acb44d497cfd3ccbad',
#   'author': 'Jeremy Howard',
#   'date': '2024-07-30T22:14:34Z',
#   'message': 'Merge pull request #4034 from kevin-vitro/3901_fixing_pickling_issue\n\nadding code to fix pickling issue',
#   'url': 'https://github.com/fastai/fastai/commit/c19f8c627162f07135a0b2acb44d497cfd3ccbad'},
#  {'sha': 'af35e99d1e84798175e68dca90193549f12bd353',
#   'author': 'Jeremy Howard',
#   'date': '2024-07-29T23:25:26Z',
#   'message': 'Merge pull request #4040 from tonyhoo/torch_24\n\nSupport PyTorch 2.4',
#   'url': 'https://github.com/fastai/fastai/commit/af35e99d1e84798175e68dca90193549f12bd353'},
#  {'sha': '04519d9b837236b3e538938d728f81d883d80c2c',
#   'author': 'Tony Hu',
#   'date': '2024-07-29T21:31:25Z',
#   'message': 'Support PyTorch 2.4',
#   'url': 'https://github.com/fastai/fastai/commit/04519d9b837236b3e538938d728f81d883d80c2c'},
#  {'sha': 'a00f6090418db26ff72fe86727d3a9ce63bf62c9',
#   'author': 'Jeremy Howard',
#   'date': '2024-07-13T20:56:40Z',
#   'message': 'fix test',
#   'url': 'https://github.com/fastai/fastai/commit/a00f6090418db26ff72fe86727d3a9ce63bf62c9'},
#  {'sha': 'ae148cefd9a4323b6e3fb58f6af6a0734651c260',
#   'author': 'Jeremy Howard',
#   'date': '2024-06-29T21:32:38Z',
#   'message': 'Merge pull request #4038 from KareimGazer/patch-1\n\nfix typo quick_start.ipynb',
#   'url': 'https://github.com/fastai/fastai/commit/ae148cefd9a4323b6e3fb58f6af6a0734651c260'},
#  {'sha': '6a17b5346b5614838396ddad3e73fe8432daa5c8',
#   'author': 'Kareim Tarek AbdelAzeem',
#   'date': '2024-06-29T21:28:37Z',
#   'message': "fix typo quick_start.ipynb\n\nchanged 'difference' to 'different'",
#   'url': 'https://github.com/fastai/fastai/commit/6a17b5346b5614838396ddad3e73fe8432daa5c8'},
#  {'sha': '715aa4a06c8b28ccc01d33207fefc634378f1947',
#   'author': 'Kevin Bird',
#   'date': '2024-06-26T15:47:30Z',
#   'message': 'matching source git diff',
#   'url': 'https://github.com/fastai/fastai/commit/715aa4a06c8b28ccc01d33207fefc634378f1947'},
#  {'sha': '6a778a9a60dbd1727681c9357215ff6867674c6e',
#   'author': 'Kevin Bird',
#   'date': '2024-06-26T15:45:42Z',
#   'message': 'removing extra newline',
#   'url': 'https://github.com/fastai/fastai/commit/6a778a9a60dbd1727681c9357215ff6867674c6e'},
#  {'sha': '97fb3780c6f662e7068d8060741f6e0659da4ed1',
#   'author': 'Kevin Bird',
#   'date': '2024-06-26T15:40:50Z',
#   'message': 'trying a less aggressive approach',
#   'url': 'https://github.com/fastai/fastai/commit/97fb3780c6f662e7068d8060741f6e0659da4ed1'},
#  {'sha': 'cc83b744c78f6eed3bf9ac6cd16423bf15ecb93d',
#   'author': 'Kevin Bird',
#   'date': '2024-06-24T14:56:34Z',
#   'message': 'adding more comprehensive test',
#   'url': 'https://github.com/fastai/fastai/commit/cc83b744c78f6eed3bf9ac6cd16423bf15ecb93d'},
#  {'sha': '630e1ecf2bec143249704025d0704ade65990b51',
#   'author': 'Kevin Bird',
#   'date': '2024-06-24T14:29:55Z',
#   'message': 'adding code to fix pickling issue',
#   'url': 'https://github.com/fastai/fastai/commit/630e1ecf2bec143249704025d0704ade65990b51'},
#  {'sha': '785ec908c7f75a272c718dd0df53822bdf5e9e0e',
#   'author': 'Jeremy Howard',
#   'date': '2024-05-25T05:16:59Z',
#   'message': 'export',
#   'url': 'https://github.com/fastai/fastai/commit/785ec908c7f75a272c718dd0df53822bdf5e9e0e'},
#  {'sha': '2fd8171a4c95586dc257c62f6097e8f889719e27',
#   'author': 'Jeremy Howard',
#   'date': '2024-05-25T05:13:26Z',
#   'message': 'call .numpy to work around sklearn bug',
#   'url': 'https://github.com/fastai/fastai/commit/2fd8171a4c95586dc257c62f6097e8f889719e27'},
#  {'sha': 'deb098a2e182d1fc0cc47f54651aac3a1d0a0bfb',
#   'author': 'Jeremy Howard',
#   'date': '2024-05-25T04:42:36Z',
#   'message': 'bump',
#   'url': 'https://github.com/fastai/fastai/commit/deb098a2e182d1fc0cc47f54651aac3a1d0a0bfb'},
#  {'sha': '6db9f9cd77d6bb1cd8a939852b0a0c48ce20e01b',
#   'author': 'Jeremy Howard',
#   'date': '2024-04-27T22:14:00Z',
#   'message': 'release',
#   'url': 'https://github.com/fastai/fastai/commit/6db9f9cd77d6bb1cd8a939852b0a0c48ce20e01b'},
#  {'sha': '3bbde65ee8b9df63068aad8b5d0214fb0db7a90c',
#   'author': 'Jeremy Howard',
#   'date': '2024-04-27T22:11:46Z',
#   'message': 'Merge pull request #4026 from warner-benjamin/pytorch23',
#   'url': 'https://github.com/fastai/fastai/commit/3bbde65ee8b9df63068aad8b5d0214fb0db7a90c'},
#  {'sha': '98850d144126368bcf095d6043e93d3073607e77',
#   'author': 'Benjamin Warner',
#   'date': '2024-04-24T22:43:27Z',
#   'message': 'Support PyTorch 2.3',
#   'url': 'https://github.com/fastai/fastai/commit/98850d144126368bcf095d6043e93d3073607e77'},
#  {'sha': '37bc4dbf1839d5476bcf52f298f9f3ab60e19a7d',
#   'author': 'Jeremy Howard',
#   'date': '2024-04-17T03:08:02Z',
#   'message': 'Merge pull request #4024 from NickOveracker/master',
#   'url': 'https://github.com/fastai/fastai/commit/37bc4dbf1839d5476bcf52f298f9f3ab60e19a7d'},
#  {'sha': 'b2c4d947391b11adcf6b515c271a34e91d69b587',
#   'author': 'Nick Overacker',
#   'date': '2024-04-17T01:03:33Z',
#   'message': 'Change `, quoting)` to `, quoting=quoting`)',
#   'url': 'https://github.com/fastai/fastai/commit/b2c4d947391b11adcf6b515c271a34e91d69b587'},
#  {'sha': '068fc05666b9740ffea610610bffc1d91e675ee8',
#   'author': 'Nick Overacker',
#   'date': '2024-04-15T02:02:51Z',
#   'message': 'Add quoting parameter into the actual pandas.from_csv call.',
#   'url': 'https://github.com/fastai/fastai/commit/068fc05666b9740ffea610610bffc1d91e675ee8'},
#  {'sha': '6c57aff8d8bbefaad5d42720e930fdaec1953879',
#   'author': 'Nick Overacker',
#   'date': '2024-04-15T02:02:15Z',
#   'message': 'Add quoting parameter into the actual pandas.from_csv call.',
#   'url': 'https://github.com/fastai/fastai/commit/6c57aff8d8bbefaad5d42720e930fdaec1953879'},
#  {'sha': 'bb38b141a44a47d83f8ac8339dcfaad04dd38763',
#   'author': 'Nick Overacker',
#   'date': '2024-04-15T01:05:25Z',
#   'message': 'Add quoting parameter to DataLoaders.from_csv() (Text ipynb)',
#   'url': 'https://github.com/fastai/fastai/commit/bb38b141a44a47d83f8ac8339dcfaad04dd38763'}]

# %%
def filter_repositories(repos, min_stars = 0, max_stars = 0, language = None):
  """ Return repos with at least min_stars and at most max_stars and optional language"""
  filtered_repos = []
  for r in repos:
    if r["stargazers_count"] < min_stars or r["stargazers_count"] > max_stars:
      continue
    if language and r["language"] != language:
      continue
    filtered_repos.append(r)
  return filtered_repos

filter_repositories(repos, min_stars= 10000, max_stars= 100000, language= "Python")
# Out:
# [{'id': 29749635,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyOTc0OTYzNQ==',
#   'name': 'data-science-ipython-notebooks',
#   'full_name': 'donnemartin/data-science-ipython-notebooks',
#   'private': False,
#   'owner': {'login': 'donnemartin',
#    'id': 5458997,
#    'node_id': 'MDQ6VXNlcjU0NTg5OTc=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5458997?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/donnemartin',
#    'html_url': 'https://github.com/donnemartin',
#    'followers_url': 'https://api.github.com/users/donnemartin/followers',
#    'following_url': 'https://api.github.com/users/donnemartin/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/donnemartin/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/donnemartin/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/donnemartin/subscriptions',
#    'organizations_url': 'https://api.github.com/users/donnemartin/orgs',
#    'repos_url': 'https://api.github.com/users/donnemartin/repos',
#    'events_url': 'https://api.github.com/users/donnemartin/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/donnemartin/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/donnemartin/data-science-ipython-notebooks',
#   'description': 'Data science Python notebooks: Deep learning (TensorFlow, Theano, Caffe, Keras), scikit-learn, Kaggle, big data (Spark, Hadoop MapReduce, HDFS), matplotlib, pandas, NumPy, SciPy, Python essentials, AWS, and various command lines.',
#   'fork': False,
#   'url': 'https://api.github.com/repos/donnemartin/data-science-ipython-notebooks',
#   'forks_url': 'https://api.github.com/repos/donnemartin/data-science-ipython-notebooks/forks',
#   'keys_url': 'https://api.github.com/repos/donnemartin/data-science-ipython-notebooks/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/donnemartin/data-science-ipython-notebooks/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/donnemartin/data-science-ipython-notebooks/teams',
#   'hooks_url': 'https://api.github.com/repos/donnemartin/data-science-ipython-notebooks/hooks',
#   'issue_events_url': 'https://api.github.com/repos/donnemartin/data-science-ipython-notebooks/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/donnemartin/data-science-ipython-notebooks/events',
#   'assignees_url': 'https://api.github.com/repos/donnemartin/data-science-ipython-notebooks/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/donnemartin/data-science-ipython-notebooks/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/donnemartin/data-science-ipython-notebooks/tags',
#   'blobs_url': 'https://api.github.com/repos/donnemartin/data-science-ipython-notebooks/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/donnemartin/data-science-ipython-notebooks/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/donnemartin/data-science-ipython-notebooks/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/donnemartin/data-science-ipython-notebooks/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/donnemartin/data-science-ipython-notebooks/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/donnemartin/data-science-ipython-notebooks/languages',
#   'stargazers_url': 'https://api.github.com/repos/donnemartin/data-science-ipython-notebooks/stargazers',
#   'contributors_url': 'https://api.github.com/repos/donnemartin/data-science-ipython-notebooks/contributors',
#   'subscribers_url': 'https://api.github.com/repos/donnemartin/data-science-ipython-notebooks/subscribers',
#   'subscription_url': 'https://api.github.com/repos/donnemartin/data-science-ipython-notebooks/subscription',
#   'commits_url': 'https://api.github.com/repos/donnemartin/data-science-ipython-notebooks/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/donnemartin/data-science-ipython-notebooks/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/donnemartin/data-science-ipython-notebooks/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/donnemartin/data-science-ipython-notebooks/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/donnemartin/data-science-ipython-notebooks/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/donnemartin/data-science-ipython-notebooks/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/donnemartin/data-science-ipython-notebooks/merges',
#   'archive_url': 'https://api.github.com/repos/donnemartin/data-science-ipython-notebooks/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/donnemartin/data-science-ipython-notebooks/downloads',
#   'issues_url': 'https://api.github.com/repos/donnemartin/data-science-ipython-notebooks/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/donnemartin/data-science-ipython-notebooks/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/donnemartin/data-science-ipython-notebooks/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/donnemartin/data-science-ipython-notebooks/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/donnemartin/data-science-ipython-notebooks/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/donnemartin/data-science-ipython-notebooks/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/donnemartin/data-science-ipython-notebooks/deployments',
#   'created_at': '2015-01-23T19:38:29Z',
#   'updated_at': '2025-07-10T22:17:34Z',
#   'pushed_at': '2024-03-20T13:52:34Z',
#   'git_url': 'git://github.com/donnemartin/data-science-ipython-notebooks.git',
#   'ssh_url': 'git@github.com:donnemartin/data-science-ipython-notebooks.git',
#   'clone_url': 'https://github.com/donnemartin/data-science-ipython-notebooks.git',
#   'svn_url': 'https://github.com/donnemartin/data-science-ipython-notebooks',
#   'homepage': '',
#   'size': 49025,
#   'stargazers_count': 28338,
#   'watchers_count': 28338,
#   'language': 'Python',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 7995,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 40,
#   'license': {'key': 'other',
#    'name': 'Other',
#    'spdx_id': 'NOASSERTION',
#    'url': None,
#    'node_id': 'MDc6TGljZW5zZTA='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': ['aws',
#    'big-data',
#    'caffe',
#    'data-science',
#    'deep-learning',
#    'hadoop',
#    'kaggle',
#    'keras',
#    'machine-learning',
#    'mapreduce',
#    'matplotlib',
#    'numpy',
#    'pandas',
#    'python',
#    'scikit-learn',
#    'scipy',
#    'spark',
#    'tensorflow',
#    'theano'],
#   'visibility': 'public',
#   'forks': 7995,
#   'open_issues': 40,
#   'watchers': 28338,
#   'default_branch': 'master',
#   'permissions': {'admin': False,
#    'maintain': False,
#    'push': False,
#    'triage': False,
#    'pull': True},
#   'score': 1.0}]

# %%
def download_file_from_repo(owner: str, repo: str, path: str, save_as: str = None):
    """Download a single file from a GitHub repo's contents."""
    url = f"https://api.github.com/repos/{owner}/{repo}/contents/{path}"
    response = requests.get(url, headers=HEADERS)

    if response.status_code == 200:
        data = response.json()
        download_url = data.get("download_url")

        if not download_url:
            print("⚠️ This path is not a downloadable file.")
            return

        file_data = requests.get(download_url)
        save_path = save_as or path.split("/")[-1]

        with open(save_path, "wb") as f:
            f.write(file_data.content)
        print(f"✅ File downloaded: {save_path}")

    else:
        print(f"❌ Error fetching file: {response.status_code}")


download_file_from_repo("fastai", "fastai", "README.md")
# Out:
# ✅ File downloaded: README.md

# %%
def download_repo_zip(owner: str, repo: str, branch: str = "main", save_as: str = None):
    """Download a full GitHub repo as a ZIP archive."""
    zip_url = f"https://github.com/{owner}/{repo}/archive/refs/heads/{branch}.zip"
    response = requests.get(zip_url)

    if response.status_code == 200:
        filename = save_as or f"{repo}-{branch}.zip"
        with open(filename, "wb") as f:
            f.write(response.content)
        print(f"✅ Repository downloaded: {filename}")
    else:
        print(f"❌ Error downloading ZIP: {response.status_code}")

download_repo_zip("fastai", "fastai", branch="main")
# Out:
# ✅ Repository downloaded: fastai-main.zip

# %% [markdown]
# ## 📘 Reflection
#
# This thest provided a valuable opportunity to worj with GithHub's API and develop a structure.
#
# In a production environment, I would further optimize the worrkflow by modularizing helper functions into reusable packages, implementing robust loggins and incorporating retry mechanisms with backoff for resilient error handling.
#
# This notebook can be shared and rerun with a minimal setup.
